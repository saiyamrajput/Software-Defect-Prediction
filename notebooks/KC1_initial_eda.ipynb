# %%
import pandas as pd
from scipy.io import arff

# Load the arff file
data = arff.loadarff('../data/raw/kc1.arff')

# Convert to a pandas DataFrame
df = pd.DataFrame(data[0])

print(df.head())

# %%
print("Shape:")
print(df.shape)

print("\nColumn names:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Shape:
# (2109, 22)
#
# Column names:
# ['loc', 'v(g)', 'ev(g)', 'iv(g)', 'n', 'v', 'l', 'd', 'i', 'e', 'b', 't', 'lOCode', 'lOComment', 'lOBlank', 'locCodeAndComment', 'uniq_Op', 'uniq_Opnd', 'total_Op', 'total_Opnd', 'branchCount', 'defects']
#
# Data types:
# loc                  float64
# v(g)                 float64
# ev(g)                float64
# iv(g)                float64
# n                    float64
# v                    float64
# l                    float64
# d                    float64
# i                    float64
# e                    float64
# b                    float64
# t                    float64
# lOCode               float64
# lOComment            float64
# lOBlank              float64
# locCodeAndComment    float64
# uniq_Op              float64
# uniq_Opnd            float64
# total_Op             float64
# total_Opnd           float64
# branchCount          float64
# defects               object
# dtype: object
#
# Missing values:
# ...

# %%
df["defects"].value_counts()
# Out:
# defects
# b'false'    1783
# b'true'      326
# Name: count, dtype: int64

# %%
df["defects"].value_counts(normalize=True) * 100
# Out:
# defects
# b'false'    84.542437
# b'true'     15.457563
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#                loc         v(g)        ev(g)        iv(g)            n  \
# count  2109.000000  2109.000000  2109.000000  2109.000000  2109.000000
# mean     20.372262     2.838028     1.674443     2.546420    49.829445
# std      29.754442     3.900763     2.200659     3.375859    83.599874
# min       1.000000     1.000000     1.000000     1.000000     0.000000
# 25%       3.000000     1.000000     1.000000     1.000000     4.000000
# 50%       9.000000     1.000000     1.000000     1.000000    16.000000
# 75%      24.000000     3.000000     1.000000     3.000000    58.000000
# max     288.000000    45.000000    26.000000    45.000000  1106.000000
#
#                  v            l            d            i              e  ...  \
# count  2109.000000  2109.000000  2109.000000  2109.000000    2109.000000  ...
# mean    258.696719     0.319583     6.771242    21.240071    5242.386240  ...
# std     516.317605     0.317029     7.863646    21.500367   17444.981211  ...
# ...

# %% [markdown]
# ## Initial EDA Findings
# * The class distribution of the data set is imbalanced.
# * The KC1 dataset consists of 2109 rows and 22 columns. Rows contain information on software modules and columns contain attributes of teh respective software modules.
# * There are 22 attribute columns out of which 21 columns are used as explanatory variates (input of the model) and 1 is response variate (output of the model).
# * There are no missing values found in the dataset.
# * There are total of 1783 non-defective modules and 326 defective modules out of 2109 software modules.
# * The data is positively rightly skewed.
